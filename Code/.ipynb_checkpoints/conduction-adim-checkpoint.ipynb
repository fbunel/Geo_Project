# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import sparse
from scipy.sparse  import linalg
# %matplotlib inline

# %%
class terre:
    def __init__(self,**kwargs):
        #N nombre initial de particules
        
        R, r, dr, dt, lmbda, rho, Cp, P, sigma, T0 = [1]*10
        
        try:
            taille = kwargs['taille']
        except:
            taille = 10
        #l'equation n'est pas definie en r=0 on decale donc le premier point
        epsilon = 3/taille
        # on fait commencer r après 0 pour l'instant
        r = np.linspace(epsilon, 1, num=taille)
        
        dt = 1
        
        
        dr=1/taille
        lmbda = 0.0001
        sigma = 5.670373E-8 
        T0 = 2.7 #2.7K fond diffus cosmologique
        c = dt/(rho*Cp)
        
        
        
        self.taille   = taille
        self.epsilon  = epsilon  #l'equation n'est pas definie en r=0
        self.R        = R    #rayon de la terre
        self.r        = r    #rayon relatif [0,1], il intervient dans la formule du fait de la sym spherique
        self.dr       = dr   #pas d'espace
        self.dt       = dt    #pas de temps
        self.lmbda    = lmbda #conductivité thermique
        self.rho      = rho  #masse volumique
        self.Cp       = Cp   #capaité calorifique
        self.P        = P    #terme de source (nucleaire)
        self.c        = c
        self.sigma    = sigma
        self.T0       = T0   #temperature du fond diffus cosmologique
        
        #condition initiales
        self.T     = np.zeros(taille)
        self.T[:] = 300
        self.rho0  = np.zeros(taille)
        self.P = np.zeros(taille)
        #self.P[:20] = 1
        
        
        #quelques matrices de base pour constuire la matrice complete
        ones = np.ones(self.taille)
        eye = sparse.eye(taille)
        d1 = sparse.dia_matrix(([-1*ones,1*ones],[0,1]), shape=(taille, taille))
        c1 = ((r+dr/2)**2)/((r*dr)**2)
        u1 = sparse.dia_matrix((c1,[0]), shape=(taille, taille))
        
        d2 = sparse.dia_matrix(([-1*ones,1*ones],[0,-1]), shape=(taille, taille))
        c2 = ((r-dr/2)**2)/((r*dr)**2) 
        # on met c2 dans une diagonale pour la multiplication avec d2
        u2 = sparse.dia_matrix((c2,[0]), shape=(taille, taille))
        #print('u \n',u2.toarray())
        #print('u \n',(u2*d2).toarray())

        #condition aux limites
        print(x)
        
        
        
        d1 = d1.tocsr()
        d1[0,0:3]  = [-2,1,1]
        d1[-1,-3:] = 0

        
        d2 = d2.tocsr()
        d2[0,0:2]  = 0
        d2[-1,-3:] = [1,1,-2]
        
        
        #print(d1.toarray())
        #print(d2.toarray())
        #on construit m, la matrice complete 
        c = self.dt*self.lmbda/(self.rho*self.Cp)
        self.m = eye - c*u1*d1 - c*u2*d2
        

        
        self.m = sparse.csc_matrix(self.m) #format csc plus efficace
        self.lu = linalg.splu(self.m) #on précalcule la décomposition LU
    
    def BC(self):
        print("sigma",self.sigma)
        #c0 = 3 * self.lmbda * self.dt / (2 * self.rho * self.Cp * (self.R**2) * (self.dr**2))
        c0 = 3 * self.lmbda * self.dt / ( self.rho * self.Cp * (self.R**2) * (self.dr**0))
        c0=0
        
        print(self.T[0],self.T[-1])
        #self.T[1] = self.T[1] + self.P[1]*self.dt/(self.rho*self.Cp) + c0*(self.T[2]-self.T[1])
        #self.T[0] = self.T[1]
        
        """
        c1 = (3*(1-2*self.dr)**2 / (self.R**2 * (1-(1-2*self.dr)**3) * self.dr) 
              * self.dt * self.lmbda/(self.rho * self.Cp))
        c2 = (3 / (self.R * (1-(1-2*self.dr)**3) ) 
              * self.dt * self.sigma/(self.rho * self.Cp))
              """
        c1 = self.dt * self.lmbda/(self.rho * self.Cp)
        c2 = self.dt * self.sigma/(self.rho * self.Cp)
        #c1,c2=0,0
        
        self.T[-1] = self.T[-1] + self.P[-1]*self.dt/(self.rho*self.Cp) - c1*(self.T[-1]-self.T[-2]) - c2*(self.T[-1]**4 - self.T0**4)
        
        print("c0,c1,c2 : {}, {}, {}".format(c0,c1,c2))
        print("T[0] , T[-1] : {}, {}".format(self.T[0],self.T[-1]))
        
        print()
        
        
    def step(self):
        self.T = self.lu.solve(self.T + self.c*self.P)
    
    def show(self):
        size = self.T.shape[0]
        y, x = np.mgrid[0:size, 0:size]
        r = np.sqrt(x**2 + y**2).astype(np.uint)
        valid = np.where(r < size)
        
        d = np.empty((size,size))
        d[valid] = self.T[r[valid]]
        
        plt.imshow(np.ma.array(d, mask=(r >= size)),cmap='plasma',interpolation='nearest',vmin=0,vmax=400)
        plt.colorbar()
        
    def anim(self):
        # %matplotlib qt4
        i=0
        #while True:
        size = self.T.shape[0]
        for _ in range(20):
            if i == 0:
                y, x = np.mgrid[0:size, 0:size]
                r = np.sqrt(x**2 + y**2).astype(np.uint)
                valid = np.where(r < size)

                d = np.empty((size,size))
                d = np.ma.array(d, mask=(r >= size))
                d[valid] = self.T[r[valid]]

                p = plt.imshow(d,cmap='plasma')
                plt.clim()
                plt.colorbar()
                i=1
            else:
                i+=1
                self.step()
                self.BC()
                d[valid] = self.T[r[valid]]
                p.set_data(d)
                plt.title("frame {}, sum : {}".format(i,(self.r*self.T).sum()))

            
            plt.pause(0.5)

t = terre(taille=6,x=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-7824a7b68516> in <module>()
#     160             plt.pause(0.5)
#     161
# --> 162 t = terre(taille=6,x=2)
#
# <ipython-input-39-7824a7b68516> in __init__(self, **kwargs)
#      62
#      63         #condition aux limites
# ---> 64         print(x)
#      65
#      66
#
# NameError: name 'x' is not defined

# %%
t = terre(taille=1000)
t.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-36e670129368> in <module>()
# ----> 1 t = terre(taille=1000)
#       2 t.show()
#
# <ipython-input-39-7824a7b68516> in __init__(self, **kwargs)
#      62
#      63         #condition aux limites
# ---> 64         print(x)
#      65
#      66
#
# NameError: name 'x' is not defined

# %%
t = terre(taille=1000)

t.T[:500] = np.linspace(100,0,500)
e1,e0=0,0
for i in range(20):
    e1,e0=(t.T*(t.r**2)).sum(),e1
    print(e1-e0)
    t.step()
    #t.BC()
#t.BC()
#t.step()
t.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-e619e25407ca> in <module>()
# ----> 1 t = terre(taille=1000)
#       2
#       3 t.T[:500] = np.linspace(100,0,500)
#       4 e1,e0=0,0
#       5 for i in range(20):
#
# <ipython-input-39-7824a7b68516> in __init__(self, **kwargs)
#      62
#      63         #condition aux limites
# ---> 64         print(x)
#      65
#      66
#
# NameError: name 'x' is not defined

# %%
t.step()
#t.BC()
t.show()

# %%
e1,e0=0,0

for i in range(10):
    e1,e0=(t.T*(t.r**2)).sum(),e1
    print(e1-e0)
    t.step()
    t.BC()
t.show()
# Out:
# 82388.9247383
# sigma 5.670373e-08
# 292.733809728 234.278285888
# c0,c1,c2 : 0, 0.01, 5.670373e-07
# T[0] , T[-1] : 292.73380972812936, -1473.925275929829
#
# -542.807232742
# sigma 5.670373e-08
# 291.483504035 232.856688769
# c0,c1,c2 : 0, 0.01, 5.670373e-07
# T[0] , T[-1] : 291.4835040354831, -1434.2613149758104
#
# -530.394329175
# sigma 5.670373e-08
# 290.146584683 231.473869962
# c0,c1,c2 : 0, 0.01, 5.670373e-07
# T[0] , T[-1] : 290.1465846833307, -1396.3947891377616
#
# -518.490315829
# sigma 5.670373e-08
# 288.730976443 230.127238448
# c0,c1,c2 : 0, 0.01, 5.670373e-07
# T[0] , T[-1] : 288.7309764430215, -1360.1892989719404
#
# -507.061205702
# sigma 5.670373e-08
# 287.244902649 228.814494788
# c0,c1,c2 : 0, 0.01, 5.670373e-07
# T[0] , T[-1] : 287.24490264856763, -1325.523992865287
#
# -496.076354648
# sigma 5.670373e-08
# 285.696655815 227.533587701
# c0,c1,c2 : 0, 0.01, 5.670373e-07
# T[0] , T[-1] : 285.69665581536026, -1292.2912236441396
#
# -485.508035586
# sigma 5.670373e-08
# 284.094413379 226.282678518
# c0,c1,c2 : 0, 0.01, 5.670373e-07
# T[0] , T[-1] : 284.09441337947834, -1260.394636075695
#
# -475.331076627
# sigma 5.670373e-08
# 282.446095181 225.060111849
# c0,c1,c2 : 0, 0.01, 5.670373e-07
# T[0] , T[-1] : 282.4460951810622, -1229.7475927829378
#
# -465.522552496
# sigma 5.670373e-08
# 280.759257976 223.864391168
# c0,c1,c2 : 0, 0.01, 5.670373e-07
# T[0] , T[-1] : 280.75925797621534, -1200.2718685970954
#
# -456.061520472
# sigma 5.670373e-08
# 279.041021706 222.694158371
# c0,c1,c2 : 0, 0.01, 5.670373e-07
# T[0] , T[-1] : 279.0410217059235, -1171.896559799181
