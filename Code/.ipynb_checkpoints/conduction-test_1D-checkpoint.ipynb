# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import sparse
from scipy.sparse  import linalg
# %matplotlib inline

# %%
class terre:
    def __init__(self,**kwargs):
        #N nombre initial de particules
        
        R, r, dr, dt, lmbda, rho, Cp, P = [1]*8
        
        taille = 1000
        #l'equation n'est pas definie en r=0 on decale donc le premier point
        epsilon = 2/taille
        r = np.linspace(epsilon, 1, num=taille).reshape((-1,1))
        dr=1/taille
        lmbda = 0.001
        c = dt/(rho*Cp)
        
        self.taille   = taille
        self.epsilon  = epsilon  #l'equation n'est pas definie en r=0
        self.R        = R    #rayon de la terre
        self.r        = r    #rayon relatif [0,1], il intervient dans la formule du fait de la sym spherique
        self.dr       = dr   #pas d'espace
        self.dt       = dt    #pas de temps
        self.lmbda    = lmbda #conductivité thermique
        self.rho      = rho  #masse volumique
        self.Cp       = Cp   #capaité calorifique
        self.P        = P    #terme de source (nucleaire)
        self.c        = c
        
        
        #condition initiales
        self.T     = np.zeros(taille)
        self.T[0:900] = 10
        self.rho0  = np.zeros(taille)
        self.P = np.zeros(taille)
        #self.P[:20] = 1
        
        #quelques matrices de base pour constuire la matrice complete
        ones = np.ones(self.taille)
        eye = sparse.eye(taille)
        d1 = sparse.dia_matrix(([-1*ones, 0*ones,1*ones],[-1,0,1]), shape=(taille, taille))
        d2 = sparse.dia_matrix(([ 1*ones,-2*ones,1*ones],[-1,0,1]), shape=(taille, taille))
        

        #condition aux limites
        d1 = d1.tocsr()
        d2 = d2.tocsr()
        d2[0,0]  = -2
        d2[0,1]  =  2
        d2[-1,-1] = -2
        d2[-1,-2] =  2
        
        d1[0, 0]  =  2
        d1[0,-1]  = -2
        
        d1[-1,-1] =  2
        d1[-1,-2] = -2
        
        #on construit m, la matrice complete 
        self.m = eye - d1*lmbda*dt/(r*dr*rho*Cp*R*R) - d2*lmbda*dt/(4*dr*dr*rho*Cp*R*R)
        self.m = sparse.csc_matrix(self.m) #format csc plus efficace
        self.lu = linalg.splu(self.m) #on précalcule la décomposition LU
        
        
    def step(self):
        self.T = self.lu.solve(self.T + self.c*self.P)
    
    def show(self):
        y, x = np.mgrid[0:self.T.shape[0], 0:self.T.shape[0]]
        r = np.sqrt(x**2 + y**2).astype(np.uint)
        valid = np.where(r < 1000)
        
        d = np.empty((self.T.shape[0],self.T.shape[0]))
        d[valid] = self.T[r[valid]]
        
        plt.imshow(np.ma.array(d, mask=(r >= 1000)),cmap='plasma')
        plt.colorbar()
        
    def anim(self):
        # %matplotlib qt4
        i=0
        while True:
            if i == 0:
                y, x = np.mgrid[0:self.T.shape[0], 0:self.T.shape[0]]
                r = np.sqrt(x**2 + y**2).astype(np.uint)
                valid = np.where(r < 1000)

                d = np.empty((self.T.shape[0],self.T.shape[0]))
                d = np.ma.array(d, mask=(r >= 1000))
                d[valid] = self.T[r[valid]]

                p = plt.imshow(d,cmap='plasma')
                plt.clim()
                plt.colorbar()
                i=1
            else:
                i+=1
                self.step()
                d[valid] = self.T[r[valid]]
                p.set_data(d)
                plt.title(i)

            
            plt.pause(0.5)

# %%
t = terre()

t.anim()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-65cf83853ee2> in <module>()
#       1 t = terre()
#       2
# ----> 3 t.anim()
#
# <ipython-input-32-ebff55206ea1> in anim(self)
#      99
#     100
# --> 101             plt.pause(0.5)
#     102
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in pause(interval)
#     287             canvas = figManager.canvas
#     288             if canvas.figure.stale:
# --> 289                 canvas.draw()
#     290             show(block=False)
#     291             canvas.start_event_loop(interval)
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_qt5agg.py in draw(self)
#     156         # The Agg draw is done here; delaying causes problems with code that
#     157         # uses the result of the draw() to update plot elements.
# --> 158         FigureCanvasAgg.draw(self)
#     159         self.update()
#     160
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     472
#     473         try:
# --> 474             self.figure.draw(self.renderer)
#     475         finally:
#     476             RendererAgg.lock.release()
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/lib/python3/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1109
#    1110         for tick in ticks_to_draw:
# -> 1111             tick.draw(renderer)
#    1112
#    1113         # scale up the axis label box to also find the neighbors, not
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in draw(self, renderer)
#     250
#     251         if self.label1On:
# --> 252             self.label1.draw(renderer)
#     253         if self.label2On:
#     254             self.label2.draw(renderer)
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /usr/lib/python3/dist-packages/matplotlib/text.py in draw(self, renderer)
#     794                     textrenderer.draw_text(gc, x, y, clean_line,
#     795                                            textobj._fontproperties, angle,
# --> 796                                            ismath=ismath, mtext=mtext)
#     797
#     798         gc.restore()
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py in draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#     198             # We pass '0' for angle here, since it will be rotated (in raster
#     199             # space) in the following call to draw_text_image).
# --> 200             font.set_text(s, 0, flags=flags)
#     201         font.draw_glyphs_to_bitmap(antialiased=rcParams['text.antialiased'])
#     202         d = font.get_descent() / 64.0
#
# KeyboardInterrupt:

# %%
t = terre()

t.step()
t.show()

# %%
t.step()
t.show()
